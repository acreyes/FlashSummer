# %%
import yt

# %%
data = yt.load("/home/flash/FLASH4.7/object/sedov_hdf5_chk_0005")
# Out:
# yt : [INFO     ] 2023-05-24 23:46:15,486 Particle file found: sedov_hdf5_chk_0005
# yt : [INFO     ] 2023-05-24 23:46:15,515 Parameters: current_time              = 0.05016158899765283
# yt : [INFO     ] 2023-05-24 23:46:15,516 Parameters: domain_dimensions         = [8 8 1]
# yt : [INFO     ] 2023-05-24 23:46:15,516 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2023-05-24 23:46:15,517 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2023-05-24 23:46:15,517 Parameters: cosmological_simulation   = 0

# %%
data.print_stats()
# Out:
# level	# grids	       # cells	     # cells^3
# ----------------------------------------------
#   0	     1	            64	             4
#   1	     4	           256	             7
#   2	    16	          1024	            11
#   3	    64	          4096	            16
#   4	   128	          8192	            21
#   5	   304	         19456	            27
# ----------------------------------------------
#    	   517	         33088
#
#
# t = 5.01615890e-02 = 5.01615890e-02 s = 1.58952484e-09 years
#
# Smallest Cell:
# 	Width: 1.266e-27 Mpc Mpc
# 	Width: 1.266e-21 pc pc
# 	Width: 2.611e-16 AU AU
# 	Width: 3.906e-03 cm cm

# %%
data.field_list
# Out:
# [('flash', 'dena'),
#  ('flash', 'dens'),
#  ('flash', 'eina'),
#  ('flash', 'eint'),
#  ('flash', 'ener'),
#  ('flash', 'enra'),
#  ('flash', 'gamc'),
#  ('flash', 'game'),
#  ('flash', 'pres'),
#  ('flash', 'prsa'),
#  ('flash', 'shok'),
#  ('flash', 'temp'),
#  ('flash', 'velx'),
#  ('flash', 'vely'),
#  ('flash', 'velz'),
#  ('flash', 'vlxa'),
#  ('flash', 'vlya'),
#  ('flash', 'vlza')]

# %%
p = yt.ProjectionPlot(data, "z", ('flash', 'dens'))
# Out:
# yt : [INFO     ] 2023-05-24 23:49:13,752 Projection completed
# yt : [INFO     ] 2023-05-24 23:49:13,752 xlim = 0.000000 1.000000
# yt : [INFO     ] 2023-05-24 23:49:13,753 ylim = 0.000000 1.000000
# yt : [INFO     ] 2023-05-24 23:49:13,753 xlim = 0.000000 1.000000
# yt : [INFO     ] 2023-05-24 23:49:13,753 ylim = 0.000000 1.000000
# yt : [INFO     ] 2023-05-24 23:49:13,757 Making a fixed resolution buffer of (('flash', 'dens')) 800 by 800

# %%
p.show()
# Out:
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
